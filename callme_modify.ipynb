# %%
import pandas as pd
df = pd.read_csv('../datasets/call-me-sexist-but/sexism_data.csv')
pd.options.display.max_colwidth=200

# %%
new_df = df[['text', 'dataset']].copy()
df.loc[:, "text"] = df["text"].apply(lambda x : x.replace('\n', '\\n'))

new_df[:20]
# Out:
#                                                                                                                                        text  \
# 0                                                                                      MENTION3481 i didn't even know random was an option!
# 1                                                                                                          Bottom two should've gone!  #mkr
# 2                                   MENTION3111 MENTION3424 ladyboner deserves so much more credit than dudeboner. #bonerdebate #reddetails
# 3                                                                          She shall now be known as Sourpuss #MKR #KatAndre #FailedFoodies
# 4                                Tarah W threw a bunch of women under the bus so she could get Wadhwa's support for her Women in Tech book.
# 5                                                                                             I just don't trust an adult who uses coupons.
# 6                                                                                                                            Not again #MKR
# 7   #MKR2016 returns in 2020 once the all the couples, intruders, gate crashers and second-chancers are eliminated MENTION786 #MKR #MKR2015
# 8                                                              MENTION526 most abuse comes from gamergate accounts that are 30-90 days old.
# 9                     Great to see the local National Park workers tucking into a free feed.  How about you empty those loo's instead. #MKR
# 10                             All my sons have grown up with computer games but I'm not interested. I see them as a male thing. MENTION203
# 11         MENTION4487 those are waaaaay more spendy. this is the drive i have. just considering using built-in or if i should go software.
# 12                 Woman are the future. Rise up, Stand up, Shine on. \n#adaywithoutwomen\n#internationalwomensday… https://t.co/Nc7PsmLiN2
# 13                                                        Apart from Ash and Robert, I'd pretty much forgotten about the rest of them. #MKR
# 14                                                                                                      Women have more intuition than men.
# 15                                                                                     Better than wadhwa. #ladylike http://t.co/KDXrCwAtfp
# 16                                                 Nimoy is not crate trained. Whelp. It's going to be a long night. http://t.co/unahvXKIsk
# 17                                                                                                                    MENTION2279 bot fight
# 18                                                                           No one should be set on a pedestal by their significant other.
# 19                                               Lo cewek ya? "MENTION4162: I have zero tolerance for cowok riwil. Riwil is girls' nature."
#
#        dataset
# 0        other
# 1        other
# 2       callme
# 3        other
# 4        other
# 5       callme
# 6        other
# 7        other
# 8        other
# 9        other
# 10      callme
# 11       other
# 12  benevolent
# 13       other
# 14      scales
# 15       other
# 16       other
# 17       other
# 18      scales
# 19      callme

# %%
df.columns[3:5]
# Out:
# Index(['toxicity', 'sexist'], dtype='object')

# %%
#new_df['label'] = [(rdf.toxicity).strip(), str(df.sexist).strip()]
new_df['label'] = df[df.columns[3:5]].apply(
    lambda x: ','.join(x.dropna().astype(str)),
    axis=1
)

new_df['source'] = 'samory2021en'
new_df['language'] = 'en'
col_order = ['text', 'label', 'language', 'source', 'dataset']
new_df = new_df.reindex(columns=col_order)

# %%
print(new_df.head(20))
# Out:
#                                                                                                                                        text  \
# 0                                                                                      MENTION3481 i didn't even know random was an option!
# 1                                                                                                          Bottom two should've gone!  #mkr
# 2                                   MENTION3111 MENTION3424 ladyboner deserves so much more credit than dudeboner. #bonerdebate #reddetails
# 3                                                                          She shall now be known as Sourpuss #MKR #KatAndre #FailedFoodies
# 4                                Tarah W threw a bunch of women under the bus so she could get Wadhwa's support for her Women in Tech book.
# 5                                                                                             I just don't trust an adult who uses coupons.
# 6                                                                                                                            Not again #MKR
# 7   #MKR2016 returns in 2020 once the all the couples, intruders, gate crashers and second-chancers are eliminated MENTION786 #MKR #MKR2015
# 8                                                              MENTION526 most abuse comes from gamergate accounts that are 30-90 days old.
# 9                     Great to see the local National Park workers tucking into a free feed.  How about you empty those loo's instead. #MKR
# 10                             All my sons have grown up with computer games but I'm not interested. I see them as a male thing. MENTION203
# 11         MENTION4487 those are waaaaay more spendy. this is the drive i have. just considering using built-in or if i should go software.
# 12                 Woman are the future. Rise up, Stand up, Shine on. \n#adaywithoutwomen\n#internationalwomensday… https://t.co/Nc7PsmLiN2
# 13                                                        Apart from Ash and Robert, I'd pretty much forgotten about the rest of them. #MKR
# 14                                                                                                      Women have more intuition than men.
# 15                                                                                     Better than wadhwa. #ladylike http://t.co/KDXrCwAtfp
# 16                                                 Nimoy is not crate trained. Whelp. It's going to be a long night. http://t.co/unahvXKIsk
# 17                                                                                                                    MENTION2279 bot fight
# 18                                                                           No one should be set on a pedestal by their significant other.
# 19                                               Lo cewek ya? "MENTION4162: I have zero tolerance for cowok riwil. Riwil is girls' nature."
#
#                 label language        source     dataset
# 0   0.118180156,False       en  samory2021en       other
# 1    0.25184965,False       en  samory2021en       other
# 2    0.11333082,False       en  samory2021en      callme
# 3    0.53115267,False       en  samory2021en       other
# 4    0.11871842,False       en  samory2021en       other
# 5    0.11958974,False       en  samory2021en      callme
# 6    0.19841516,False       en  samory2021en       other
# 7    0.44726166,False       en  samory2021en       other
# 8      0.254602,False       en  samory2021en       other
# 9    0.39294234,False       en  samory2021en       other
# 10    0.09102523,True       en  samory2021en      callme
# 11   0.26062253,False       en  samory2021en       other
# 12   0.29967123,False       en  samory2021en  benevolent
# 13   0.11920435,False       en  samory2021en       other
# 14    0.32142898,True       en  samory2021en      scales
# 15   0.13178632,False       en  samory2021en       other
# 16   0.15342756,False       en  samory2021en       other
# 17   0.17153381,False       en  samory2021en       other
# 18   0.08134023,False       en  samory2021en      scales
# 19   0.27580786,False       en  samory2021en      callme

# %%
new_df.to_csv('formatted/samory2021en.csv', index=False, sep='\t', header=False)
