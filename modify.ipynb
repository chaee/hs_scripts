# %%
import pandas as pd
pd.options.display.max_colwidth=200

# %%
ds= '/Users/yunchaewon/gesis/datasets/fox-news-comments/annotated-threads/all-comments.txt'
df = pd.read_csv(ds, sep='\:', index_col=False, header=None, lineterminator='\n')
source = 'gao2018'
# Out:
# <ipython-input-33-dd3dacd06cb4>:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(ds, sep='\:', index_col=False, header=None, lineterminator='\n')

# %%
df = df.rename(columns={0: "label", 1: "text"})
df
# Out:
#       label  \
# 0         1
# 1         1
# 2         0
# 3         1
# 4         1
# ...     ...
# 1523      1
# 1524      1
# 1525      1
# 1526      1
# 1527      1
#
#                                                                                                                                                                                                          text
# 0                                                                                                                                                                     barryswallows Merkel would never say NO
# 1                                           PostApocalypticHero Expect more and more women to be asking .. "why are men no longer interested in me"! We're not going touch you until you pull our pants down!
# 2                                                                                                           californiamojo Groping people in public wasn't already illegal? What's up with that, Deutschland?
# 3     MikeSte Merkel, possible the only person in charge who is worse than what we have. Obama is trying his hardest though to get to Merkel's level. "A 21-year-old Iraqi man was convicted of sexual ass...
# 4                                                                                              scientist They know very well, no means NO! They need to pass a law making it legal to castrate those animals.
# ...                                                                                                                                                                                                       ...
# 1523                                                                                                                                                           toorotten No, 10000 Loose nuts off their meds!
# 1524                                                                                                                                                                    randwolf13 Just another ugly leftist.
# 1525                                             creatingfalserealitiesleadstoinsanity @randwolf13 True. Most leftists ,esp female leftists have a violent hatred towards pretty women.Gee, I wonder why?????
# 1526                                                                                                                                                               KhaosDominus First, lets get this straight
# 1527                                                                                                         leftisrighthippy White privilege ...work all your life to take care of people who dont work ....
#
# [1528 rows x 2 columns]

# %%
new_df = df.copy()
new_df.loc[:, "text"] = new_df["text"].apply(lambda x : x.replace('\n', '\\n'))

# %%
new_df['source'] = source 
new_df['language'] = 'en'

col_order = ['text', 'label', 'language', 'source'] #, 'dataset']
new_df = new_df.reindex(columns=col_order)
print(new_df.head())
new_df.to_csv(f'formatted/{source}.csv', index=False, sep='\t')
# Out:
#                                                                                                                                                                                                       text  \
# 0                                                                                                                                                                  barryswallows Merkel would never say NO
# 1                                        PostApocalypticHero Expect more and more women to be asking .. "why are men no longer interested in me"! We're not going touch you until you pull our pants down!
# 2                                                                                                        californiamojo Groping people in public wasn't already illegal? What's up with that, Deutschland?
# 3  MikeSte Merkel, possible the only person in charge who is worse than what we have. Obama is trying his hardest though to get to Merkel's level. "A 21-year-old Iraqi man was convicted of sexual ass...
# 4                                                                                           scientist They know very well, no means NO! They need to pass a law making it legal to castrate those animals.
#
#    label language   source
# 0      1       en  gao2018
# 1      1       en  gao2018
# 2      0       en  gao2018
# 3      1       en  gao2018
# 4      1       en  gao2018

# %%
new_df = df[['text']].copy()
tox_codes = df[['tox_codes_oc', 'tox_codes_ic']].copy()
new_df = new_df.rename(columns={"hateSpeech": "text"})

new_df.loc[:, "text"] = new_df["text"].apply(lambda x : x.replace('\n', '\\n'))
new_df['label'] = tox_codes[tox_codes.columns[:]].apply(
    lambda x: ','.join(x.dropna().astype(str)),
    axis=1
)

# %%
new_df
# Out:
#                                                                                                                                                                                                          text  \
# 0                                                                                                                                                                     barryswallows Merkel would never say NO
# 1                                           PostApocalypticHero Expect more and more women to be asking .. "why are men no longer interested in me"! We're not going touch you until you pull our pants down!
# 2                                                                                                           californiamojo Groping people in public wasn't already illegal? What's up with that, Deutschland?
# 3     MikeSte Merkel, possible the only person in charge who is worse than what we have. Obama is trying his hardest though to get to Merkel's level. "A 21-year-old Iraqi man was convicted of sexual ass...
# 4                                                                                              scientist They know very well, no means NO! They need to pass a law making it legal to castrate those animals.
# ...                                                                                                                                                                                                       ...
# 1523                                                                                                                                                           toorotten No, 10000 Loose nuts off their meds!
# 1524                                                                                                                                                                    randwolf13 Just another ugly leftist.
# 1525                                             creatingfalserealitiesleadstoinsanity @randwolf13 True. Most leftists ,esp female leftists have a violent hatred towards pretty women.Gee, I wonder why?????
# 1526                                                                                                                                                               KhaosDominus First, lets get this straight
# 1527                                                                                                         leftisrighthippy White privilege ...work all your life to take care of people who dont work ....
#
#       label language   source
# 0         1       en  gao2018
# 1         1       en  gao2018
# 2         0       en  gao2018
# 3         1       en  gao2018
# 4         1       en  gao2018
# ...     ...      ...      ...
# 1523      1       en  gao2018
# 1524      1       en  gao2018
# 1525      1       en  gao2018
# 1526      1       en  gao2018
# 1527      1       en  gao2018
#
# [1528 rows x 4 columns]
